# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# # Read The Dataset

# %%
df=pd.read_csv("DoctorVisits - DA.csv")
df.head(15)
# Out:
#     Unnamed: 0  visits  gender   age  income  illness  reduced  health  \
# 0            1       1  female  0.19    0.55        1        4       1
# 1            2       1  female  0.19    0.45        1        2       1
# 2            3       1    male  0.19    0.90        3        0       0
# 3            4       1    male  0.19    0.15        1        0       0
# 4            5       1    male  0.19    0.45        2        5       1
# 5            6       1  female  0.19    0.35        5        1       9
# 6            7       1  female  0.19    0.55        4        0       2
# 7            8       1  female  0.19    0.15        3        0       6
# 8            9       1  female  0.19    0.65        2        0       5
# 9           10       1    male  0.19    0.15        1        0       0
# 10          11       1    male  0.19    0.45        1        0       0
# 11          12       1    male  0.19    0.25        2        0       2
# ...

# %% [markdown]
# # Display Complete Information About The Columns Of The Dataset Such As Column Name, Count, Data Type And Overall Memory Usage

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5190 entries, 0 to 5189
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  5190 non-null   int64
#  1   visits      5190 non-null   int64
#  2   gender      5190 non-null   object
#  3   age         5190 non-null   float64
#  4   income      5190 non-null   float64
#  5   illness     5190 non-null   int64
#  6   reduced     5190 non-null   int64
#  7   health      5190 non-null   int64
#  8   private     5190 non-null   object
#  9   freepoor    5190 non-null   object
#  10  freerepat   5190 non-null   object
#  11  nchronic    5190 non-null   object
#  12  lchronic    5190 non-null   object
# dtypes: float64(2), int64(5), object(6)
# memory usage: 527.2+ KB

# %% [markdown]
# # Find Out The Total No: Of People Based On Their Count Of Illeness, Gender, Age, Income, Visits

# %%
df['illness'].value_counts()
# Out:
# 1    1638
# 0    1554
# 2     946
# 3     542
# 4     274
# 5     236
# Name: illness, dtype: int64

# %%
df['gender'].value_counts()
# Out:
# female    2702
# male      2488
# Name: gender, dtype: int64

# %%
df['age']=df['age']*100
df['age'].value_counts()
# Out:
# 22.0    1213
# 72.0     822
# 19.0     752
# 27.0     523
# 62.0     316
# 67.0     315
# 32.0     301
# 57.0     273
# 52.0     222
# 47.0     181
# 37.0     146
# 42.0     126
# Name: age, dtype: int64

# %%
df['income']=df['income']*100000
df['income'].value_counts()
# Out:
# 25000.0     1195
# 90000.0      589
# 55000.0      467
# 35000.0      462
# 65000.0      455
# 75000.0      441
# 45000.0      400
# 110000.0     361
# 15000.0      249
# 150000.0     215
# 130000.0     162
# 6000.0        80
# 0.0           79
# 1000.0        35
# Name: income, dtype: int64

# %%
df['visits'].value_counts()
# Out:
# 0    4141
# 1     782
# 2     174
# 3      30
# 4      24
# 7      12
# 6      12
# 5       9
# 8       5
# 9       1
# Name: visits, dtype: int64

# %% [markdown]
# # Describing The Info Of The Datatype

# %%
df.describe()
# Out:
#         Unnamed: 0       visits          age         income      illness  \
# count  5190.000000  5190.000000  5190.000000    5190.000000  5190.000000
# mean   2595.500000     0.301734    40.638536   58315.992293     1.431985
# std    1498.368279     0.798134    20.478182   36890.669837     1.384152
# min       1.000000     0.000000    19.000000       0.000000     0.000000
# 25%    1298.250000     0.000000    22.000000   25000.000000     0.000000
# 50%    2595.500000     0.000000    32.000000   55000.000000     1.000000
# 75%    3892.750000     0.000000    62.000000   90000.000000     2.000000
# max    5190.000000     9.000000    72.000000  150000.000000     5.000000
#
#            reduced       health
# count  5190.000000  5190.000000
# mean      0.861850     1.217534
# std       2.887628     2.124266
# min       0.000000     0.000000
# 25%       0.000000     0.000000
# 50%       0.000000     0.000000
# 75%       0.000000     2.000000
# max      14.000000    12.000000

# %%
df.dropna(axis = 0)
# Out:
#       Unnamed: 0  visits  gender   age    income  illness  reduced  health  \
# 0              1       1  female  19.0   55000.0        1        4       1
# 1              2       1  female  19.0   45000.0        1        2       1
# 2              3       1    male  19.0   90000.0        3        0       0
# 3              4       1    male  19.0   15000.0        1        0       0
# 4              5       1    male  19.0   45000.0        2        5       1
# ...          ...     ...     ...   ...       ...      ...      ...     ...
# 5185        5186       0  female  22.0   55000.0        0        0       0
# 5186        5187       0    male  27.0  130000.0        0        0       1
# 5187        5188       0  female  37.0   25000.0        1        0       1
# 5188        5189       0  female  52.0   65000.0        0        0       0
# 5189        5190       0    male  72.0   25000.0        0        0       0
#
#      private freepoor freerepat nchronic lchronic
# ...

# %%
df.fillna("20")
# Out:
#       Unnamed: 0  visits  gender   age    income  illness  reduced  health  \
# 0              1       1  female  19.0   55000.0        1        4       1
# 1              2       1  female  19.0   45000.0        1        2       1
# 2              3       1    male  19.0   90000.0        3        0       0
# 3              4       1    male  19.0   15000.0        1        0       0
# 4              5       1    male  19.0   45000.0        2        5       1
# ...          ...     ...     ...   ...       ...      ...      ...     ...
# 5185        5186       0  female  22.0   55000.0        0        0       0
# 5186        5187       0    male  27.0  130000.0        0        0       1
# 5187        5188       0  female  37.0   25000.0        1        0       1
# 5188        5189       0  female  52.0   65000.0        0        0       0
# 5189        5190       0    male  72.0   25000.0        0        0       0
#
#      private freepoor freerepat nchronic lchronic
# ...

# %%
df.ffill(axis = 0)
# Out:
#       Unnamed: 0  visits  gender   age    income  illness  reduced  health  \
# 0              1       1  female  19.0   55000.0        1        4       1
# 1              2       1  female  19.0   45000.0        1        2       1
# 2              3       1    male  19.0   90000.0        3        0       0
# 3              4       1    male  19.0   15000.0        1        0       0
# 4              5       1    male  19.0   45000.0        2        5       1
# ...          ...     ...     ...   ...       ...      ...      ...     ...
# 5185        5186       0  female  22.0   55000.0        0        0       0
# 5186        5187       0    male  27.0  130000.0        0        0       1
# 5187        5188       0  female  37.0   25000.0        1        0       1
# 5188        5189       0  female  52.0   65000.0        0        0       0
# 5189        5190       0    male  72.0   25000.0        0        0       0
#
#      private freepoor freerepat nchronic lchronic
# ...

# %%
df.bfill(axis = 0)
# Out:
#       Unnamed: 0  visits  gender   age    income  illness  reduced  health  \
# 0              1       1  female  19.0   55000.0        1        4       1
# 1              2       1  female  19.0   45000.0        1        2       1
# 2              3       1    male  19.0   90000.0        3        0       0
# 3              4       1    male  19.0   15000.0        1        0       0
# 4              5       1    male  19.0   45000.0        2        5       1
# ...          ...     ...     ...   ...       ...      ...      ...     ...
# 5185        5186       0  female  22.0   55000.0        0        0       0
# 5186        5187       0    male  27.0  130000.0        0        0       1
# 5187        5188       0  female  37.0   25000.0        1        0       1
# 5188        5189       0  female  52.0   65000.0        0        0       0
# 5189        5190       0    male  72.0   25000.0        0        0       0
#
#      private freepoor freerepat nchronic lchronic
# ...

# %%
df.drop_duplicates()
# Out:
#       Unnamed: 0  visits  gender   age    income  illness  reduced  health  \
# 0              1       1  female  19.0   55000.0        1        4       1
# 1              2       1  female  19.0   45000.0        1        2       1
# 2              3       1    male  19.0   90000.0        3        0       0
# 3              4       1    male  19.0   15000.0        1        0       0
# 4              5       1    male  19.0   45000.0        2        5       1
# ...          ...     ...     ...   ...       ...      ...      ...     ...
# 5185        5186       0  female  22.0   55000.0        0        0       0
# 5186        5187       0    male  27.0  130000.0        0        0       1
# 5187        5188       0  female  37.0   25000.0        1        0       1
# 5188        5189       0  female  52.0   65000.0        0        0       0
# 5189        5190       0    male  72.0   25000.0        0        0       0
#
#      private freepoor freerepat nchronic lchronic
# ...

# %%
df.drop_duplicates(subset=['private'])
# Out:
#    Unnamed: 0  visits  gender   age   income  illness  reduced  health  \
# 0           1       1  female  19.0  55000.0        1        4       1
# 2           3       1    male  19.0  90000.0        3        0       0
#
#   private freepoor freerepat nchronic lchronic
# 0     yes       no        no       no       no
# 2      no       no        no       no       no

# %%
df.drop_duplicates(subset=['freerepat','illness'])
# Out:
#      Unnamed: 0  visits  gender   age   income  illness  reduced  health  \
# 0             1       1  female  19.0  55000.0        1        4       1
# 2             3       1    male  19.0  90000.0        3        0       0
# 4             5       1    male  19.0  45000.0        2        5       1
# 5             6       1  female  19.0  35000.0        5        1       9
# 6             7       1  female  19.0  55000.0        4        0       2
# 11           12       1    male  19.0  25000.0        2        0       2
# 82           83       1  female  19.0  25000.0        1        0       9
# 103         104       1  female  19.0  45000.0        0        0       0
# 152         153       2  female  22.0  55000.0        5        2       3
# 303         304       1    male  27.0  25000.0        3        0       3
# 505         506       1    male  52.0  25000.0        4        2       7
# 621         622       1  female  57.0  25000.0        0        0       0
#
# ...

# %%
df.shape
# Out:
# (5190, 13)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'visits', 'gender', 'age', 'income', 'illness', 'reduced',
#        'health', 'private', 'freepoor', 'freerepat', 'nchronic', 'lchronic'],
#       dtype='object')

# %%
df.isna().sum()
# Out:
# Unnamed: 0    0
# visits        0
# gender        0
# age           0
# income        0
# illness       0
# reduced       0
# health        0
# private       0
# freepoor      0
# freerepat     0
# nchronic      0
# lchronic      0
# dtype: int64

# %% [markdown]
# # Analyzing The Variables

# %%
df.visits.unique()
# Out:
# array([1, 2, 3, 4, 8, 5, 7, 6, 9, 0], dtype=int64)

# %%
df.gender.unique()
# Out:
# array(['female', 'male'], dtype=object)

# %%
df.freerepat.unique()
# Out:
# array(['no', 'yes'], dtype=object)

# %%
df.private.unique()
# Out:
# array(['yes', 'no'], dtype=object)

# %%
df.nchronic.unique()
# Out:
# array(['no', 'yes'], dtype=object)

# %%
df.age.unique()
# Out:
# array([19., 22., 27., 32., 37., 42., 47., 52., 57., 62., 67., 72.])

# %%
df.income.unique()
# Out:
# array([ 55000.,  45000.,  90000.,  15000.,  35000.,  65000.,  25000.,
#             0.,   6000., 110000.,  75000.,   1000., 130000., 150000.])

# %%
df.nunique()
# Out:
# Unnamed: 0    5190
# visits          10
# gender           2
# age             12
# income          14
# illness          6
# reduced         15
# health          13
# private          2
# freepoor         2
# freerepat        2
# nchronic         2
# lchronic         2
# dtype: int64

# %% [markdown]
# # Plotting The Data

# %%
sns.histplot(df['age'], bins=60)
# Out:
# <AxesSubplot:xlabel='age', ylabel='Count'>

# %%
sns.histplot(df['age'], bins=65)
plt.xlabel('Age')
plt.ylabel('visit')
plt.title('Distribution of Patients Ages')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
gender_counts = df['gender'].value_counts()
sns.barplot(x=gender_counts.index,y=gender_counts.values)
plt.xlabel('gender')
plt.ylabel('visit')
plt.title('Distribution of Patient Gender')
plt.show()

# %%
sns.histplot(df['visits'], bins=35)
plt.xlabel('visits')
plt.ylabel('income')
plt.title('visit analysis')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # Observations

# %%
labels=['visits','illness','reduced','health']
sizes=[25,20,13,5]
plt.pie(sizes,labels=labels,autopct = '%1.1f%%')
plt.title('overall analysis of patients')
plt.show()

# %%
x = [16,14,12,18,20]
y = [10,12,14,9,7]
plt.plot(x,y)
plt.xlabel('nchronic')
plt.ylabel('Ichronic')
plt.title('Disease analysis')
plt.show()

# %%
df.hist(figsize=(20,25))
# Out:
# array([[<AxesSubplot:title={'center':'Unnamed: 0'}>,
#         <AxesSubplot:title={'center':'visits'}>,
#         <AxesSubplot:title={'center':'age'}>],
#        [<AxesSubplot:title={'center':'income'}>,
#         <AxesSubplot:title={'center':'illness'}>,
#         <AxesSubplot:title={'center':'reduced'}>],
#        [<AxesSubplot:title={'center':'health'}>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %%
x= (df[['health']]==1).sum()
y= (df[['health']]==0).sum()
percent= ((x*y)/(x+y))*100
percent
# Out:
# health    64702.468174
# dtype: float64

# %% [markdown]
# # Visualize And Analyze The Maximum, Minimum And Medium Income

# %%
a=list(df.income)
plt.boxplot(a)
plt.show()

# %% [markdown]
# # Find Out The No Of The Days Of Reduced Activity Of Male And Female Separatly Due To Illness

# %%
df.groupby(['gender','reduced']).mean()
# Out:
#                  Unnamed: 0    visits        age         income   illness  \
# gender reduced
# female 0        2524.038512  0.229322  46.575492   48273.522976  1.462144
#        1        1985.768421  0.400000  32.568421   54210.526316  2.242105
#        2        1622.618182  0.672727  39.145455   56018.181818  2.236364
#        3         997.311111  1.333333  40.311111   51600.000000  2.733333
#        4        1237.740741  0.851852  45.888889   46666.666667  2.222222
#        5        1169.055556  1.444444  40.166667   61444.444444  2.222222
#        6        1382.545455  1.363636  42.636364   62272.727273  2.363636
#        7        1034.846154  1.384615  43.615385   47346.153846  2.653846
#        8        1883.090909  1.090909  47.181818   40454.545455  2.181818
#        9        1349.000000  0.500000  57.000000   82500.000000  3.000000
#        10       1099.428571  2.142857  51.285714   42142.857143  2.571429
# ...

# %% [markdown]
# # Visualize Is There Is Any Missing Values In The Dataset Based On A Heat Map

# %%
#missing values
sns.heatmap(df.isnull(),cbar=False,cmap="viridis")
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Find Out THe Correlation Between Variables In The Given Dataset Correlation Between Different Variables

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(),cbar=True,annot=True,cmap='Blues')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Analyze How The Income Of A Patient Affects The No Of Visits To The Hospital

# %%
plt.figure(figsize=(10,10))
plt.scatter(x='income',y='visits',data=df)
plt.xlabel("INCOME")
plt.ylabel("VISITS")
# Out:
# Text(0, 0.5, 'VISITS')

# %% [markdown]
# # Count And Visualize The Number Of Males And Females Affected By Illness

# %%
sns.histplot(df.gender,bins=2)
# Out:
# <AxesSubplot:xlabel='gender', ylabel='Count'>

# %% [markdown]
# # Visualize The Percentage Of People Getting Govt Health Insurance Due To Low Income, Due To Old Age And Also The Percentage Of People Having Private Health Insurance

# %%
label=['yes','no']
y=df[df['freepoor']=='yes']
n=df[df['freepoor']=='no']
x=[y.shape[0],n.shape[0]]
plt.figure(figsize=(5,5))
plt.pie(x,labels=label)
plt.title('People Getting Govt Health Insurance Due To Low Income')
plt.show()

y=df[df['private']=='yes']
n=df[df['private']=='no']
x=[y.shape[0],n.shape[0]]
plt.figure(figsize=(5,5))
plt.pie(x,labels=label)
plt.title('People Having Private Health Insurance')
plt.show()

y=df[df['freerepat']=='yes']
n=df[df['freerepat']=='no']
x=[y.shape[0],n.shape[0]]
plt.figure(figsize=(5,5))
plt.pie(x,labels=label)
plt.title('People Getting Govt Health Insurance Due To Old Age, Disability Or Veteran Status')
plt.show()

# %% [markdown]
# # Plot A Horizontal Bar Chart To Analyze The Reduced Days Of Activity Due To Illness Based On Gender

# %%
db=df.groupby('gender')['reduced'].sum().to_frame().reset_index()
plt.barh(db['gender'],db['reduced'],color=['orange','yellow'])
plt.title('Bar Chart')
plt.xlabel('Reduced activity')
plt.ylabel('Gender')
plt.show()

# %% [markdown]
# # Conclusion
#
# (a)The dataset contains information about patient visits to doctors, including attributes like age, gender, income, and various health-related factors.
#
# (b) The income variable does not seem to have a significant impact on other variables in the dataset. It appears to be consistent across different categories.
#
# (c)Female gender is more in number comparable to male gender.
#
# (d)No strong correlations are observed, so the variables are mostly independent of each other.
#
# (e)This analysis provides insights into patient demographics, health conditions, and insurance coverage.
